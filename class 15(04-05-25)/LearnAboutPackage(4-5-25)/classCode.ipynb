# %%
print('hello world')
# Out:
# hello world

# %%
import package_demo.package2.fibonic_series as ch

print(ch.fibonacci(5))
# Out:
# [0, 1, 1, 2, 3, 5]

# %%
import package_demo.package1.sum as sum1

print(sum1.sum(5,10))
# Out:
# 15

# %%
from meme.generator import generate_meme
from PIL import Image
import matplotlib.pyplot as plt

meme = generate_meme()
print(meme)  # Shows caption and path

# Display the actual image
try:
    img = Image.open(meme.split('\n')[1].replace("Image: ", ""))
    plt.imshow(img)
    plt.axis('off')  # Hide axes
    plt.show()
except Exception as e:
    print(f"Couldn't display image: {e}")
# Out:
# 🎉 MEME GENERATED 🎉
# Image: e:\Programming Data by Adeel\Python\Python course by EXD\Classes\class 15(04-05-25)\LearnAboutPackage(4-5-25)\meme\images\image.jpg
# Caption: Me: I'll just fix this one thing... 3 hours later

# %%
from meme.generator import generate_meme
from PIL import Image
import matplotlib.pyplot as plt

caption = generate_meme() 
image_path = "meme/images/image_1.jpg"
print(f"\n🎉 MEME GENERATED 🎉")
print(f"Caption: {caption}")

try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.title(caption)
    plt.axis('off')
    plt.show()
except Exception as e:
    print(f"Error displaying image: {e}")
# Out:
# 🎉 MEME GENERATED 🎉
# Caption: 🎉 MEME GENERATED 🎉
# Image: e:\Programming Data by Adeel\Python\Python course by EXD\Classes\class 15(04-05-25)\LearnAboutPackage(4-5-25)\meme\images\image.jpg
# Caption: That feeling when your code runs perfectly first try
# Error displaying image: [Errno 2] No such file or directory: 'E:\\Programming Data by Adeel\\Python\\Python course by EXD\\Classes\\class 15(04-05-25)\\LearnAboutPackage(4-5-25)\\meme\\images\\image_1.jpg'
